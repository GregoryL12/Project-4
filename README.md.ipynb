# %% [markdown]
# # Chicago Crimes Statistics Tableau

# %% [markdown]
# ## Main Dashboard
#
# ![Tableau%20snip.PNG](attachment:Tableau%20snip.PNG)

# %% [markdown]
# ### Link to Tableau:
#
# https://public.tableau.com/views/CoreProjectDashboard_16947865955320/MainDashboard?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link
